# %%
# Dependencies and Setup mike
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import scipy.stats as st
import scipy.stats as sts
from scipy.stats import linregress

# Import API key
from api_keys import g_key

# %%
# Name of the CSV file
top_20 = "Resources/top_20_ca_wildfires.csv"
ca_rainfall_df = "Resources/ca_rainfall_df.csv"

# %%
# read the CSV in pandas
top_20 = pd.read_csv(top_20)
top_20
# Out:
#     index                fire_name                cause      month  year  \
# 0       0        Mendocino Complex  Under Investigation       July  2018
# 1       1                   Thomas           Powerlines   December  2017
# 2       2                    Cedar        Human Related    October  2003
# 3       3                     Rush            Lightning     August  2012
# 4       4                      Rim        Human Related     August  2013
# 5       5                     Zaca        Human Related       July  2007
# 6       6                     Carr        Human Related       July  2018
# 7       7                 Matilija         Undetermined  September  1932
# 8       8                    Witch           Powerlines    October  2007
# 9       9  Klamath Theater Complex            Lightning       June  2008
# 10     10              Marble Cone            Lightning       July  1977
# 11     11                   Laguna           Powerlines  September  1970
# ...

# %%
index = top_20["index"]
fire_name = top_20["fire_name"]
cause = top_20["cause"]
month = top_20["month"]
year = top_20["year"]
county = top_20["county"]
acres = top_20["acres"]
structures = top_20["structures"]
deaths = top_20["deaths"]

# %%
# Rename column year 
summary_top20_df = pd.DataFrame({"Index": index, "Fire Name": fire_name, "Cause": cause, "Month": month, 
                                 "Year": year, "County": county, "Acres": acres, 
                                 "Structures": structures, "Deaths": deaths})

summary_top20_df
# Out:
#     Index                Fire Name                Cause      Month  Year  \
# 0       0        Mendocino Complex  Under Investigation       July  2018
# 1       1                   Thomas           Powerlines   December  2017
# 2       2                    Cedar        Human Related    October  2003
# 3       3                     Rush            Lightning     August  2012
# 4       4                      Rim        Human Related     August  2013
# 5       5                     Zaca        Human Related       July  2007
# 6       6                     Carr        Human Related       July  2018
# 7       7                 Matilija         Undetermined  September  1932
# 8       8                    Witch           Powerlines    October  2007
# 9       9  Klamath Theater Complex            Lightning       June  2008
# 10     10              Marble Cone            Lightning       July  1977
# 11     11                   Laguna           Powerlines  September  1970
# ...

# %%
# read the CSV in pandas
ca_rainfall_df = pd.read_csv(ca_rainfall_df)
ca_rainfall_df
# Out:
#     Index         County      Month  Year  Rainfall (in)
# 0       0         Colusa       July  2018           0.00
# 1       1        Ventura   December  2017           0.01
# 2       2      San Diego    October  2003           0.01
# 3       3         Lassen     August  2012           0.05
# 4       4       Tuolumne     August  2013           0.10
# 5       5          Butte   November  2018           6.08
# 6       6         Fresno       July  2015           0.56
# 7       7         Tulare       July  2002           0.01
# 8       8       Tuolumne     August  1987           0.03
# 9       9        Trinity     August  1999           0.32
# 10     10       Monterey       July  1977           0.00
# 11     11      San Diego  September  1970           0.01
# 12     12       Monterey       June  2008           0.00
# 13     13        Ventura  September  2006           0.01
# 14     14    Los Angeles     August  2009           0.01
# ...

# %%
#Merge on year
merge_df = pd.merge(summary_top20_df, ca_rainfall_df, on="Index", left_index=True)
merge_df
# Out:
#     Index                Fire Name                Cause    Month_x  Year_x  \
# 0       0        Mendocino Complex  Under Investigation       July    2018
# 1       1                   Thomas           Powerlines   December    2017
# 2       2                    Cedar        Human Related    October    2003
# 3       3                     Rush            Lightning     August    2012
# 4       4                      Rim        Human Related     August    2013
# 5       5                     Zaca        Human Related       July    2007
# 6       6                     Carr        Human Related       July    2018
# 7       7                 Matilija         Undetermined  September    1932
# 8       8                    Witch           Powerlines    October    2007
# 9       9  Klamath Theater Complex            Lightning       June    2008
# 10     10              Marble Cone            Lightning       July    1977
# ...

# %%
merge_drop_df = merge_df.drop(['County_x','Month_x', 'Year_x'], axis = 1) 
merge_drop_df
# Out:
#     Index                Fire Name                Cause   Acres  Structures  \
# 0       0        Mendocino Complex  Under Investigation  459123         280
# 1       1                   Thomas           Powerlines  281893        1063
# 2       2                    Cedar        Human Related  273246        2820
# 3       3                     Rush            Lightning  271911           0
# 4       4                      Rim        Human Related  257314         112
# 5       5                     Zaca        Human Related  240207           1
# 6       6                     Carr        Human Related  229651        1614
# 7       7                 Matilija         Undetermined  220000           0
# 8       8                    Witch           Powerlines  197990        1650
# 9       9  Klamath Theater Complex            Lightning  192038           0
# 10     10              Marble Cone            Lightning  177866           0
# ...

# %%
# rename
final_df = merge_drop_df.rename(columns={"County_y": "County", "Month_y": "Month", "Year_y": "Year"})
final_df
# Out:
#     Index                Fire Name                Cause   Acres  Structures  \
# 0       0        Mendocino Complex  Under Investigation  459123         280
# 1       1                   Thomas           Powerlines  281893        1063
# 2       2                    Cedar        Human Related  273246        2820
# 3       3                     Rush            Lightning  271911           0
# 4       4                      Rim        Human Related  257314         112
# 5       5                     Zaca        Human Related  240207           1
# 6       6                     Carr        Human Related  229651        1614
# 7       7                 Matilija         Undetermined  220000           0
# 8       8                    Witch           Powerlines  197990        1650
# 9       9  Klamath Theater Complex            Lightning  192038           0
# 10     10              Marble Cone            Lightning  177866           0
# ...

# %%
# create output csv
final_df.to_csv("Resources/final_df.csv")

# %%
# Is there a correlation between total amount of rainfall in a specific area and the total number of wildfires?

# %%
# Is there a correlation between total number of acres burned and rainfall?
# Summary Stats
mean_numpy = np.mean(final_df["Acres"])
print(f"The mean Acres burned is {mean_numpy}")
median_numpy = np.median(final_df["Acres"])
print(f"The median Acres burned is {median_numpy}")
mode_scipy = sts.mode(final_df["Acres"])
print(f"The mode Acres burned is {mode_scipy}")
print("----------------------------------------")
mean_numpy = np.mean(final_df["Rainfall (in)"])
print(f"The mean Rainfall (in) is {mean_numpy}")
median_numpy = np.median(final_df["Rainfall (in)"])
print(f"The median Rainfall (in) is {median_numpy}")
mode_scipy = sts.mode(final_df["Rainfall (in)"])
print(f"The mode Rainfall (in) is {mode_scipy}")
# Out:
# The mean Acres burned is 210266.2
# The median Acres burned is 184952.0
# The mode Acres burned is ModeResult(mode=array([140948], dtype=int64), count=array([1]))
# ----------------------------------------
# The mean Rainfall (in) is 0.402
# The median Rainfall (in) is 0.02
# The mode Rainfall (in) is ModeResult(mode=array([0.01]), count=array([6]))

# %%
# Histogram of the Acres burned data
# Normal test of the data
plt.hist(final_df["Acres"])
plt.hist(final_df["Acres"], color = 'black')
plt.xlabel('Acres Burned')
plt.ylabel('Counts')
plt.title('Acres Burned Counts')
plt.grid(axis='y', alpha=0.75)
# plt.rcParams.update({'font.size': 12})
plt.show()
print(sts.normaltest(final_df["Acres"]))
# Out:
# NormaltestResult(statistic=20.272844016362036, pvalue=3.96102748210523e-05)

# %%
# Histogram of the Rainfall (in) data
# Normal test of the data

plt.hist(final_df["Rainfall (in)"])
plt.hist(final_df["Rainfall (in)"], color = 'black')
plt.xlabel('Rainfall (in)')
plt.ylabel('Counts')
plt.title('Rainfall (in) Counts')
plt.grid(axis='y', alpha=0.75)
plt.show()
print(sts.normaltest(final_df["Rainfall (in)"]))
# Out:
# NormaltestResult(statistic=50.45383027497202, pvalue=1.1068530352725875e-11)

# %%
# Scatter Plot
plt.scatter(final_df["Acres"],final_df["Rainfall (in)"])
clb = plt.colorbar()
plt.xlabel("Acres Burned")
plt.ylabel("Rainfall (in)")
plt.title('Rainfall (in) Compared to Acres Burned')
clb.set_label("Rainfall Compared to Acres Burned")
Axes.set_autoscalex_on
plt.show()

# %%
acres_burned = final_df["Acres"]
rainfall = final_df["Rainfall (in)"]

# %%
# Calculate the correlation coefficient between Acres Burned and Rainfall (in)
# A coefficient of 0.07 which is near 0 shows that Acres Burned appears unrelated to Rainfall (in)
print(f"The correlation coefficient between Acres Burned and Rainfall (in) is {round(st.pearsonr(acres_burned,rainfall)[0],2)}")
# Out:
# The correlation coefficient between Acres Burned and Rainfall (in) is 0.07

# %%
# Remove the outlier, Zaca wildfire in 2018 and redo scatter
mod_df = final_df.drop([5])
mod_df
# Out:
#     Index                Fire Name                Cause   Acres  Structures  \
# 0       0        Mendocino Complex  Under Investigation  459123         280
# 1       1                   Thomas           Powerlines  281893        1063
# 2       2                    Cedar        Human Related  273246        2820
# 3       3                     Rush            Lightning  271911           0
# 4       4                      Rim        Human Related  257314         112
# 6       6                     Carr        Human Related  229651        1614
# 7       7                 Matilija         Undetermined  220000           0
# 8       8                    Witch           Powerlines  197990        1650
# 9       9  Klamath Theater Complex            Lightning  192038           0
# 10     10              Marble Cone            Lightning  177866           0
# 11     11                   Laguna           Powerlines  175425         382
# ...

# %%
# Scatter Plot
plt.scatter(mod_df["Acres"], mod_df["Rainfall (in)"])
clb = plt.colorbar()
plt.xlabel("Acres Burned")
plt.ylabel("Rainfall (in)")
plt.title('Rainfall (in) Compared to Acres Burned')
clb.set_label("Rainfall Compared to Acres Burned")

plt.show()

# %%
acres_burned_mod = mod_df["Acres"]
rainfall_mod = mod_df["Rainfall (in)"]

# %%
# Calculate the correlation coefficient between Acres Burned and Rainfall (in) with Zaca dropped as an outlier
# A coefficient of -0.15 is still near 0 but does show a slightly stronger correlation trend negative after removal of
# the Zaca wildfire of 2018
print(f"The correlation coefficient between Acres Burned and Rainfall (in) is {round(st.pearsonr(acres_burned_mod,rainfall_mod)[0],2)}")
# Out:
# The correlation coefficient between Acres Burned and Rainfall (in) is -0.15

# %%
# Add the linear regression equation and line to plot using the mod_df with removal of the Zaca wildfire
# As stated above the correlation is not a good fit, a value above at least .50 would allow us to confirm that there
# is a relationship
x_values = mod_df['Acres']
y_values = mod_df['Rainfall (in)']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Acres Burned')
plt.ylabel('Rainfall(in)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.022473739329444586
